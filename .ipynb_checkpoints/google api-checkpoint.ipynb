# %%
from googleapiclient.discovery import build
import pprint

my_api_key = "AIzaSyBDwrrdkFcL8QEbQT-wqlm8DrEaG1IO1nk"
my_cse_id = "015303713816810430314:e1skftpzsik"

def google_search(search_term, api_key, cse_id, **kwargs):
    service = build("customsearch", "v1", developerKey=api_key)
    res = service.cse().list(q=search_term, cx=cse_id, **kwargs).execute()
    return res['items']

results = google_search('movie star', my_api_key, my_cse_id, num=10)

# %%
for result in results:
    pprint.pprint(result)
# Out:
# {u'cacheId': u'NKsNDaH9BKcJ',
#  u'displayLink': u'variety.com',
#  u'formattedUrl': u'variety.com/2017/film/reviews/the-star-review-1202616378/',
#  u'htmlFormattedUrl': u'variety.com/2017/<b>film</b>/reviews/the-<b>star</b>-review-1202616378/',
#  u'htmlSnippet': u'Nov 16, 2017 <b>...</b> Sure enough, \u201cThe <b>Star</b>\u201d offers a playful retelling of Jesus&#39; nativity, as seen from <br>\nthe animals&#39; point of view, while keeping the necessary irreverence that entails to <br>\na benign minimum. As kid-friendly Christmas <b>movies</b> go, this one actually goes <br>\nout of its way to remind what the holiday represents, which should&nbsp;...',
#  u'htmlTitle': u'<b>Film</b> Review: &#39;The <b>Star</b>&#39;',
#  u'kind': u'customsearch#result',
#  u'link': u'http://variety.com/2017/film/reviews/the-star-review-1202616378/',
#  u'pagemap': {u'article': [{u'headline': u"Film Review: 'Kepler's Dream'"},
# ...

# %%
pprint.pprint(results[1]['htmlSnippet'])
# Out:
# u'Aug 25, 2017 <b>...</b> In a Washington restaurant one recent afternoon, Carl King sat side by side with <br>\nNnamdi Asomugha, who plays him in the new <b>film</b> \u201cCrown Heights.\u201d Asomugha <br>\ntried to explain how touched he was by King&#39;s real-life story. But King had to <br>\nadmit that initially he had no idea who Asomugha was. \u201cNever knew a&nbsp;...'

# %%
pprint.pprint(results[2]['pagemap']['metatags'][0]['og:url'])
# Out:
# u'http://www.vulture.com/2017/06/jon-hamm-why-he-never-became-a-movie-star.html'

# %%
results[1].keys()
# Out:
# [u'kind',
#  u'title',
#  u'displayLink',
#  u'htmlTitle',
#  u'formattedUrl',
#  u'htmlFormattedUrl',
#  u'pagemap',
#  u'snippet',
#  u'htmlSnippet',
#  u'link']

# %%
from bs4 import BeautifulSoup

# %%
import urllib2

# %%
for result in results:
    try:
        response = urllib2.urlopen(result['formattedUrl'])
        print response.info()
        html = response.read()
    except (HTTPError,TypeError,ValueError) as e:
        pass
    # do something
    response.close()
# Out:
# Content-Type: text/html; charset=utf-8
# Content-Length: 4544
# Connection: close
# Date: Fri, 01 Dec 2017 16:19:34 GMT
# Cache-Control: private
# Server: Microsoft-IIS/8.5
# X-AspNet-Version: 4.0.30319
# X-Powered-By: ASP.NET
# Age: 29
# X-Cache: Hit from cloudfront
# Via: 1.1 01af0adaf4294a897372414c6adda42a.cloudfront.net (CloudFront)
# X-Amz-Cf-Id: GaIrntcjUxAfoRawu7irfSUemR-t-309JMlUBVhbwnd5IUMwh0cPow==
#
# X-Frame-Options: SAMEORIGIN
# Strict-Transport-Security: max-age=31536000
# X-Content-Type-Options: nosniff
# P3P: CP="This is not a P3P policy! See http://support.google.com/accounts/answer/151657?hl=en for more info."
# Expires: Tue, 27 Apr 1971 19:44:06 EST
# X-XSS-Protection: 1; mode=block; report=https://www.google.com/appserve/security-bugs/log/youtube
# Content-Type: text/html; charset=utf-8
# Cache-Control: no-cache
# Date: Fri, 01 Dec 2017 16:20:03 GMT
# Server: YouTube Frontend Proxy
# ...

# %%
response = urllib2.urlopen(results[1]['formattedUrl'])
html = response.read()
soup = BeautifulSoup(html, "html.parser")
response.close()

# %%
print(soup.get_text())
# Out:
# @font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:local('Roboto Regular'),local('Roboto-Regular'),url(//fonts.gstatic.com/s/roboto/v18/zN7GBFwfMP4uA6AR0HCoLQ.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:local('Roboto Medium'),local('Roboto-Medium'),url(//fonts.gstatic.com/s/roboto/v18/RxZJdnzeo3R5zSexge8UUaCWcynf_cDxXwCLxiixG1c.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:local('Roboto Italic'),local('Roboto-Italic'),url(//fonts.gstatic.com/s/roboto/v18/W4wDsBUluyw0tK3tykhXEfesZW2xOQ-xsNqO47m55DA.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:italic;font-weight:500;src:local('Roboto Medium Italic'),local('Roboto-MediumItalic'),url(//fonts.gstatic.com/s/roboto/v18/OLffGBTaF0XFOW1gnuHF0Z0EAVxt0G0biEntp43Qt6E.ttf)format('truetype');}if (document.fonts && document.fonts.load) {document.fonts.load("400 10pt Roboto", "E");document.fonts.load("500 10pt Ro
# ...

# %%
import re

# %%
for tag in soup.find_all(re.compile('p')):
    print tag.contents
# Out:
# [u'if (document.fonts && document.fonts.load) {document.fonts.load("400 10pt Roboto", "E");document.fonts.load("500 10pt Roboto", "E");}']
# ...

# %%
soup.b

# %%
from pytrends.request import TrendReq

pytrends = TrendReq(hl='en-US', tz=360)

# %%
kw_list = ['Michael Flynn','hello']
pytrends.build_payload(kw_list, cat=0, timeframe='today 5-y', geo='', gprop='news')

# %%
pytrends.related_topics()['Michael Flynn']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-143-86c032fed473> in <module>()
# ----> 1 pytrends.related_topics()['Michael Flynn']
#
# KeyError: 'Michael Flynn'

# %%
list1=pytrends.related_topics()['Michael Flynn']['title'].tolist()

# %%
list1
# Out:
# [u'Michael Flynn',
#  u'Donald Trump',
#  u'Russia',
#  u'Barack Obama',
#  u'National security',
#  u'Lara Flynn Boyle',
#  u'Jefferson Sessions',
#  u'Vince Flynn',
#  u'CNN',
#  u'Immunity',
#  u'General',
#  u'Hillary Rodham Clinton',
#  u'James Comey',
#  u'Dismissal',
#  u'Federal Bureau of Investigation',
#  u'Errol Flynn',
#  u'Cabinet of the United States',
#  u'Mike Pence',
#  u'Fox News',
#  u'President of the United States',
#  u'James Mattis',
#  u'Michael Connelly',
#  u'Steve Bannon',
#  u'Vladimir Putin',
#  u'Paul Manafort']

# %%
title=pytrends.trending_searches()['title']

# %%
for name in title.values:
    print name
# Out:
# Michael Flynn
# World Cup draw
# Jimbo Fisher
# Aaron Boone
# USC football
# Dallas Cowboys Score
# Earthquake New York
# Full Moon December 2017
# December
# Jimmy Kimmel
# Carol Burnett
# Jesse Williams
# Marshall
# Ruby Rose
# Pac 12 Championship
# Sandra Bullock
# Kate Winslet
# 25 Days Of Christmas 2017
# Fletcher Cox

# %%
date='201711'

# %%
cid='basketball_players'

# %%
response = urllib2.urlopen('https://trends.google.com/trends/topcharts')
html = response.read()
soup = BeautifulSoup(html, "html.parser")
response.close()

# %%
soup.title
# Out:
# <title>Google Trends - Top Charts</title>

# %%
print(tag)
# Out:
# None

# %%
soup = BeautifulSoup('<b class="boldest">Extremely bold</b>')
tag = soup.b
# Out:
# C:\Users\GuoHanqing\AppData\Local\Continuum\Anaconda3\envs\python2.7\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html.parser"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file C:\Users\GuoHanqing\AppData\Local\Continuum\Anaconda3\envs\python2.7\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html.parser")
#
#   markup_type=markup_type))

# %%
tag.name
# Out:
# u'b'

# %%
pytrends.related_topics()['Michael Flynn']['title']
# Out:
# 0                       Michael Flynn
# 1                        Donald Trump
# 2                              Russia
# 3                        Barack Obama
# 4                   National security
# 5                    Lara Flynn Boyle
# 6                         Vince Flynn
# 7                  Jefferson Sessions
# 8                                 CNN
# 9                             General
# 10                        James Comey
# 11                           Immunity
# 12             Hillary Rodham Clinton
# 13                          Dismissal
# 14       Cabinet of the United States
# 15                        Errol Flynn
# 16                   Michael Connelly
# 17                           Fox News
# 18     President of the United States
# 19                         Mike Pence
# 20    Federal Bureau of Investigation
# 21                       Steve Bannon
# 22                     Vladimir Putin
# 23                      Jared Kushner
# 24                      Paul Manafort
# ...

# %%
a=None

# %%
try:
    list3=a['hello']
except TypeError:
    pass
for item in list3:
    print(item)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-160-52443334f6f9> in <module>()
#       1 try:
# ----> 2     list3=a['hello']
#       3 except TypeError:
#       4     pass
#       5 for item in list3:
#
# TypeError: 'NoneType' object has no attribute '__getitem__'

# %%
if a is not None:
    list3=a['hello']

# %%
list3
# Out:
# []
